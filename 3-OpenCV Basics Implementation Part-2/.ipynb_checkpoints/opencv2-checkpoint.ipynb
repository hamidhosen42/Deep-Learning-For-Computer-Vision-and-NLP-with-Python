# %%
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25853 sha256=c18bb766ff1b59d40eb80a87d303f8c30fa61f7d04b4c65bc6ffcfee0483211f
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import matplotlib.pyplot as plt
import numpy as np
import imutils
import cv2

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
plt.figure(figsize=(14, 10))
imagedata = plt.imread("../input/catimagedatas/cat.jpg")
plt.imshow(imagedata)
plt.grid(False)
plt.show()

# %%
# Ch_last
#CH -1st

# %%
len(imagedata.shape)
# Out:
# 3

# %%
len(imagedata.shape)
# Out:
# 3

# %%
def catimageShow(imageTitle, image):
    if len(image.shape) == 3:
        imageVariable = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     if image.shape[2] == 1:
#     imageVariable = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    plt.figure(figsize=(4, 2))
    plt.imshow(imageVariable)
    plt.title(imageTitle)
    plt.show()

# %%
imagedata.shape
# Out:
# (280, 300, 3)

# %%
cv2.split(imagedata)
# Out:
# (array([[ 39,  39,  40, ..., 207, 202, 201],
#         [ 40,  40,  40, ..., 203, 199, 197],
#         [ 40,  40,  40, ..., 199, 198, 198],
#         ...,
#         [ 32,  30,  26, ...,  36,  43,  57],
#         [ 32,  30,  26, ...,  42,  46,  55],
#         [ 32,  29,  25, ...,  51,  44,  40]], dtype=uint8),
#  array([[ 44,  44,  44, ..., 204, 199, 199],
#         [ 45,  45,  44, ..., 200, 196, 195],
#         [ 45,  45,  44, ..., 196, 195, 195],
#         ...,
#         [ 30,  28,  24, ...,  23,  30,  46],
#         [ 30,  28,  24, ...,  29,  33,  45],
#         [ 30,  27,  23, ...,  38,  31,  30]], dtype=uint8),
#  array([[ 40,  40,  43, ..., 171, 164, 161],
#         [ 41,  41,  43, ..., 169, 161, 157],
#         [ 41,  41,  43, ..., 165, 162, 160],
#         ...,
#         [ 31,  29,  25, ...,  17,  24,  40],
#         [ 31,  29,  25, ...,  21,  25,  36],
#         [ 31,  28,  24, ...,  30,  23,  21]], dtype=uint8))

# %%
name, age = ("Mejbah", 320)

# %%
def imageHistogram(image, imageTitle, mask = None):
    color_Channel = cv2.split(image)
    color_com = ('b', 'g', 'r')
    plt.figure(figsize = (4, 2))
    plt.title(imageTitle)
    plt.xlabel("Bins")
    plt.ylabel("Pixel Information")
    
    for (color_Channel, color_com) in zip(color_Channel, color_com):
        histogram = cv2.calcHist([color_Channel], [0], mask, [256], [0, 256])
        plt.plot(histogram, color = color_com)
        plt.xlim([0, 256])
        plt.show()

# %%
image_argument = {"Image":"../input/catimagedatas/cat.jpg"}
image = cv2.imread(image_argument["Image"])
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
smaplehisto = cv2.calcHist([image],[0], None, [256], [0, 256])
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")
plt.plot(smaplehisto)
plt.show()

# %%
image_argument = {"Image":"../input/catimagedatas/cat.jpg"}
image = cv2.imread(image_argument["Image"])
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
smaplehisto = cv2.calcHist([image],[1], None, [256], [0, 256])
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")
plt.plot(smaplehisto)#line
plt.show()

# %%
color_Channel = cv2.split(image)
color_com = ('b', 'g', 'r')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])
    #plt.show()

# %%
cv2.split(image)
# Out:
# (array([[ 39,  39,  40, ..., 207, 202, 201],
#         [ 40,  40,  40, ..., 203, 199, 197],
#         [ 40,  40,  40, ..., 199, 199, 199],
#         ...,
#         [ 32,  30,  26, ...,  36,  41,  57],
#         [ 32,  30,  26, ...,  42,  44,  55],
#         [ 32,  29,  25, ...,  51,  42,  40]], dtype=uint8),
#  array([[ 44,  44,  44, ..., 204, 199, 198],
#         [ 45,  45,  44, ..., 200, 196, 194],
#         [ 45,  45,  44, ..., 195, 194, 194],
#         ...,
#         [ 30,  28,  24, ...,  23,  30,  46],
#         [ 30,  28,  24, ...,  29,  34,  45],
#         [ 30,  27,  23, ...,  38,  32,  30]], dtype=uint8),
#  array([[ 40,  40,  43, ..., 173, 166, 163],
#         [ 41,  41,  43, ..., 169, 163, 159],
#         [ 41,  41,  43, ..., 166, 164, 162],
#         ...,
#         [ 31,  29,  25, ...,  17,  24,  40],
#         [ 31,  29,  25, ...,  21,  25,  36],
#         [ 31,  28,  24, ...,  30,  23,  21]], dtype=uint8))

# %%
color_Channel = cv2.split(image)
color_com = ('b', 'g', 'r')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])
    plt.show()

# %%
color_Channel = cv2.split(image)
color_com = ('r', 'g', 'b')
plt.figure(figsize = (4, 2))
plt.title("imageTitle")
plt.xlabel("Bins")
plt.ylabel("Pixel Information")

for (color_Channel, color_com) in zip(color_Channel, color_com):
    histogram = cv2.calcHist([color_Channel], [0],None, [256], [0, 256])
    plt.plot(histogram, color = color_com)
    plt.xlim([0, 256])
    plt.show()

# %%
color = ["B", "G", "R"]
fig = plt.figure(figsize=(20, 18))
ax = fig.add_subplot(131)
hist = cv2.calcHist([color_Channel[1], color_Channel[0]], [0, 1], None, [32, 32], [0, 256, 0, 256])
p = ax.imshow(hist, interpolation = "nearest")
ax.set_title("Image Generate for Green and Blue")
plt.colorbar(p)


ax = fig.add_subplot(132)
hist = cv2.calcHist([color_Channel[1], color_Channel[2]], [0, 1], None, [32, 32], [0, 256, 0, 256])
p = ax.imshow(hist, interpolation = "nearest")
ax.set_title("Image Generate for Green and Red")
plt.colorbar(p)



ax = fig.add_subplot(133)
hist = cv2.calcHist([color_Channel[0], color_Channel[2]], [0, 1], None, [32, 32], [0, 256, 0, 256])
p = ax.imshow(hist, interpolation = "nearest")
ax.set_title("Image Generate for Blue and Red")
plt.colorbar(p)

print("Image Shape: {} with {}".format(hist.shape, hist.flatten().shape[0]))
# Out:
# Image Shape: (32, 32) with 1024

# %%
a = 3
b = 4
print("A is {} and B is {}".format(b, a))
# Out:
# A is 4 and B is 3

# %%
def summ(a, b):
    return a, b

# %%
image = cv2.imread("../input/catimagedatas/cat.jpg")
imageHistogram(image, "Image Title")
catimageShow("orginal image", image)

# %%
image.shape[:2]
# Out:
# (280, 300)

# %%
def catimageShow(imageTitle, image):
    imageVariable = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(4, 2))
    plt.imshow(imageVariable)
    plt.title(imageTitle)
    plt.show()

# %%
mask = np.zeros(image.shape[:2], dtype= "uint8")
cv2.rectangle(mask, (60, 90), (100, 120), 255, -1)
catimageShow("Applied Mask", mask)

# %%
mask = np.zeros(image.shape[:2], dtype= "uint8")
cv2.rectangle(mask, (60, 90), (100, 120), 25, -1)
catimageShow("Applied Mask", mask)

# %%
mask = np.zeros(image.shape[:2], dtype= "uint8")
cv2.rectangle(mask, (60, 90), (100, 120), 200, -1)
catimageShow("Applied Mask", mask)

# %%
mask = np.zeros(image.shape[:2], dtype= "uint8")
cv2.rectangle(mask, (160, 190), (200, 220), 200, -1)
catimageShow("Applied Mask", mask)

# %%
image = cv2.imread("../input/catimagedatas/cat.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurImage = cv2.GaussianBlur(gray, (5, 5), 0)
catimageShow("Orginal Image", image)
catimageShow("Blur Image", blurImage)

# %%
cannyBlurWide = cv2.Canny(blurImage, 20, 250)
cannyBlurMiddle = cv2.Canny(blurImage, 15, 120)
cannyBlurFit = cv2.Canny(blurImage, 240, 250)

catimageShow("cannyBlurWide",cannyBlurWide)
catimageShow("cannyBlurMiddle", cannyBlurMiddle)
catimageShow("cannyBlurFit", cannyBlurFit)
